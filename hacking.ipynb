# %%
from typing import Tuple

import numpy as np
from rdkit.Chem import rdmolfiles

from qcio import Structure, view
from qcio.utils import _rdkit_determine_connectivity, _rdkit_mol_from_structure

# %%
zero = Structure.open("0.xyz")
zero_r = Structure.open("0-rotated.xyz")
four = Structure.open("4.xyz")
four_r = Structure.open("4-rotated.xyz")
four_reorder = Structure.open("4-reordered.xyz")
four_shuffled = Structure.open("4-shuffled.xyz")
ethanol = Structure.open("ethanol.xyz")

# %%
# view.view(zero, zero_r, four, four_r, four_reorder, four_shuffled, show_indices=False)

# %%
# view.view(four, show_indices=True, width=1200, height=800, same_viewer=True)

# %%
mol = _rdkit_mol_from_structure(four)
_rdkit_determine_connectivity(mol, four.charge)
ranks = np.array(rdmolfiles.CanonicalRankAtoms(mol, breakTies=False))
print(ranks)
# Out:
# [44 53 38 58 71 67 20 52  4 20 20 28 67 20 20 20 37 49 54 51 54 49  1  3
#  63 63  1 31 31 31 31 31 31 39 59 39  5  5 39 59 39  5  5 48 62 43 12 12
#  46 56 69 46 56 69 29 29 65 65 26 26 14 14 14 14 14 14  0 45 61  9  9  9]
# !!! Warning !!! Distance between atoms 68 and 67 (0.984529 A) is suspicious.

# %%
np.where(ranks == 71)
# Out:
# (array([4]),)

# %%
view.view(ethanol, show_indices=True)
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_17424292448165631"  style="position: relative; width: 600px; height: 450px;">
#         <p id="3dmolwarning_17424292448165631" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17424292448165631 = null;
# var warn = document.getElementById("3dmolwarning_17424292448165631");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17424292448165631 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17424292448165631"),{backgroundColor:"white"});
# viewer_17424292448165631.zoomTo();
# 	viewer_17424292448165631.addModel("6\nqcio_charge=0 qcio_multiplicity=1 qcio__identifiers_smiles=CO qcio__identifiers_canonical_smiles=CO qcio__identifiers_canonical_smiles_program=rdkit\nC  -0.37102858874547051 0.00726064866862581 -0.00945235459001515\nO  0.91813463390543726 -0.50257999216011229 -0.29654678198568296\nH  -0.52273071797269410 0.02868995381497038 1.07251276161688658\nH  -0.46536883591028144 1.01497995181514034 -0.42142659952414441\nH  -1.12031947993714098 -0.64274720586361211 -0.46735367969525399\nH  1.56131298866014401 0.09439664372498588 0.12226665417820623\n","xyz");
# 	viewer_17424292448165631.addLabel(" ",{"position": {"x": 300.0, "y": 0, "z": 0}, "alignment": "topCenter", "fontSize": 24, "backgroundOpacity": 0, "fontColor": "black", "useScreen": true});
# 	viewer_17424292448165631.addLabel(" ",{"position": {"x": 300.0, "y": 450, "z": 0}, "alignment": "bottomCenter", "fontSize": 20, "backgroundOpacity": 0, "fontColor": "black", "useScreen": true});
# 	viewer_17424292448165631.addLabel("0",{"position": {"x": -0.3710285887454705, "y": 0.00726064866862581, "z": -0.00945235459001515}});
# 	viewer_17424292448165631.addLabel("1",{"position": {"x": 0.9181346339054373, "y": -0.5025799921601123, "z": -0.29654678198568296}});
# 	viewer_17424292448165631.addLabel("2",{"position": {"x": -0.5227307179726941, "y": 0.02868995381497038, "z": 1.0725127616168866}});
# 	viewer_17424292448165631.addLabel("3",{"position": {"x": -0.46536883591028144, "y": 1.0149799518151403, "z": -0.4214265995241444}});
# 	viewer_17424292448165631.addLabel("4",{"position": {"x": -1.120319479937141, "y": -0.6427472058636121, "z": -0.467353679695254}});
# 	viewer_17424292448165631.addLabel("5",{"position": {"x": 1.561312988660144, "y": 0.09439664372498588, "z": 0.12226665417820623}});
# 	viewer_17424292448165631.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17424292448165631.zoomTo();
# viewer_17424292448165631.render();
# });
# </script></div>

# %%
def kabsch(P: np.ndarray, Q: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Compute the optimal rotation matrix that aligns P onto Q using the Kabsch algorithm.

    Parameters:
        P (np.ndarray): An N x 3 array of coordinates (the structure to rotate).
        Q (np.ndarray): An N x 3 array of coordinates (the reference structure).

    Returns:
        R (np.ndarray): The optimal 3x3 rotation matrix.
        centroid_P (np.ndarray): The centroid of P.
        centroid_Q (np.ndarray): The centroid of Q.
    """
    # Compute centroids
    centroid_P = np.mean(P, axis=0)
    centroid_Q = np.mean(Q, axis=0)

    # Center the coordinates
    P_centered = P - centroid_P
    Q_centered = Q - centroid_Q

    # Compute covariance matrix
    H = np.dot(P_centered.T, Q_centered)
    # Singular Value Decomposition
    U, S, Vt = np.linalg.svd(H)
    # Compute rotation matrix
    R = np.dot(Vt.T, U.T)

    # Correct for reflection (ensure a proper rotation with det(R)=1)
    if np.linalg.det(R) < 0:
        Vt[-1, :] *= -1
        R = np.dot(Vt.T, U.T)

    return R, centroid_P, centroid_Q

# %%
view.view(four, four_r, show_indices=True)
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_17424301617775578"  style="position: relative; width: 1200px; height: 450px;">
#         <p id="3dmolwarning_17424301617775578" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17424301617775578 = null;
# var warn = document.getElementById("3dmolwarning_17424301617775578");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_17424301617775578 = null;
# viewergrid_17424301617775578 = $3Dmol.createViewerGrid(document.getElementById("3dmolviewer_17424301617775578"),{rows: 1, cols: 2, control_all: false},{backgroundColor:"white"});
# viewer_17424301617775578 = viewergrid_17424301617775578[0][0];
# viewergrid_17424301617775578[0][0].zoomTo();viewergrid_17424301617775578[0][1].zoomTo();	viewergrid_17424301617775578[0][0].addModel("72\nqcio_charge=0 qcio_multiplicity=1 -147.45806658\nN  -0.28636203900000001 -0.39186230349999995 0.88846946309999997\nC  -0.29573041750000001 0.25310785780000000 2.05310875559999984\nS  1.10773407820000003 0.86869448800000015 2.78773476589999980\nN  -1.50138653159999991 0.48388886180000001 2.58852291140000013\nC  -1.79025459610000004 1.37885809610000010 3.68922970089999991\nC  -2.28905037999999994 2.72258729300000013 3.15821736729999980\nH  -2.52900244900000004 3.38426463620000018 3.98574098480000005\nC  0.74116764690000003 -1.13334883030000011 0.43233244949999999\nH  -2.30652167399999986 0.21856368129999998 2.03172383990000016\nH  -3.18093676320000007 2.56977932220000005 2.55472013400000009\nH  -1.52020220170000009 3.19715995779999984 2.54954115580000007\nH  -0.85333756679999995 1.52324830009999990 4.23878743139999958\nC  -2.83100316529999985 0.72542625189999999 4.59360712800000037\nH  -3.03383798290000062 1.36361945639999993 5.44914709570000078\nH  -2.47186030999999984 -0.23591420450000000 4.95491335819999978\nH  -3.75474456460000017 0.57069013660000001 4.04084914959999963\nNa 1.14642296759999995 1.67534143739999997 0.12872073940000001\nC  0.89632480859999997 -1.28245607419999996 -0.95777065870000000\nC  1.89573432909999995 -2.07971360390000015 -1.47871367949999999\
# 	viewergrid_17424301617775578[0][0].addLabel("4",{"position": {"x": -1.7902545961, "y": 1.3788580961, "z": 3.6892297009}});
# 	viewergrid_17424301617775578[0][0].addLabel("5",{"position": {"x": -2.28905038, "y": 2.722587293, "z": 3.1582173673}});
# 	viewergrid_17424301617775578[0][0].addLabel("6",{"position": {"x": -2.529002449, "y": 3.3842646362, "z": 3.9857409848}});
# 	viewergrid_17424301617775578[0][0].addLabel("7",{"position": {"x": 0.7411676469,

# %%
R, centroid_P, centroid_Q = kabsch(four_r.geometry[:3], four.geometry[:3])
rotated = Structure(symbols=four_r.symbols, geometry=np.dot(four_r.geometry - centroid_P, R.T) + centroid_Q)

# %%
view.view(four, rotated, same_viewer=True, show_indices=False)
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_17424304421328564"  style="position: relative; width: 600px; height: 450px;">
#         <p id="3dmolwarning_17424304421328564" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17424304421328564 = null;
# var warn = document.getElementById("3dmolwarning_17424304421328564");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17424304421328564 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17424304421328564"),{backgroundColor:"white"});
# viewer_17424304421328564.zoomTo();
# 	viewer_17424304421328564.addModel("72\nqcio_charge=0 qcio_multiplicity=1 -147.45806658\nN  -0.28636203900000001 -0.39186230349999995 0.88846946309999997\nC  -0.29573041750000001 0.25310785780000000 2.05310875559999984\nS  1.10773407820000003 0.86869448800000015 2.78773476589999980\nN  -1.50138653159999991 0.48388886180000001 2.58852291140000013\nC  -1.79025459610000004 1.37885809610000010 3.68922970089999991\nC  -2.28905037999999994 2.72258729300000013 3.15821736729999980\nH  -2.52900244900000004 3.38426463620000018 3.98574098480000005\nC  0.74116764690000003 -1.13334883030000011 0.43233244949999999\nH  -2.30652167399999986 0.21856368129999998 2.03172383990000016\nH  -3.18093676320000007 2.56977932220000005 2.55472013400000009\nH  -1.52020220170000009 3.19715995779999984 2.54954115580000007\nH  -0.85333756679999995 1.52324830009999990 4.23878743139999958\nC  -2.83100316529999985 0.72542625189999999 4.59360712800000037\nH  -3.03383798290000062 1.36361945639999993 5.44914709570000078\nH  -2.47186030999999984 -0.23591420450000000 4.95491335819999978\nH  -3.75474456460000017 0.57069013660000001 4.04084914959999963\nNa 1.14642296759999995 1.67534143739999997 0.12872073940000001\nC  0.89632480859999997 -1.28245607419999996 -0.95777065870000000\nC  1.89573432909999995 -2.07971360390000015 -1.47871367949999999\nC  2.78383099910000009 -2.76922735999999992 -0.66339117370000000\nC  2.61577449880000001 -2.64539741659999983 0.71225748140000000\nC  1.62819099519999999 -1.85395827309999994 1.26050112590000007\nH  0.20646367720000000 -0.77753908699999996 -1.61712190889999996\nH  3.56889471419999982 -3.38027422000000000 -1.07719644479999999\nC  2.02448510050000019 -2.12832153289999981 -2.97076581120000016\nC  3.57137766790000022 -3.32660079600000014 1.64351396849999998\nH  1.51707755070000005 -1.79428065619999999 2.33321127000000006\nF  0.88577619249999995 -2.50756382650000020 -3.58125117599999987\nF  2.98296997259999985 -2.95147462469999988 -3.41415453739999997\nF  2.31370249920000015 -0.90882049960000000 -3.48222558050000064\nF  4.23128159969999995 -4.35